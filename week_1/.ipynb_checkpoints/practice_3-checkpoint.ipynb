# %%
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
T = float(input("Enter Time: "))

A = P * (1 + (R/100) * T)

print("Simple Interest Amount =", A)
# Out:
# Enter Principal:  90
# Enter Rate:  90
# Enter Time:  56790
# Simple Interest Amount = 4600080.0

# %%
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: ")) / 100
T = float(input("Enter Time: "))
n = int(input("Enter number of times interest is compounded per year: "))

A = P * (1 + R/n) ** (n*T)

print("Compound Interest Amount =", A)
# Out:
# Enter Principal:  1223
# Enter Rate:  1245
# Enter Time:  5365
# Enter number of times interest is compounded per year:  67
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[4], line 6
#       3 T = float(input("Enter Time: "))
#       4 n = int(input("Enter number of times interest is compounded per year: "))
# ----> 6 A = P * (1 + R/n) ** (n*T)
#       8 print("Compound Interest Amount =", A)
#
# OverflowError: (34, 'Result too large')

# %%
PMT = float(input("Enter Payment per period: "))
R = float(input("Enter Rate: ")) / 100
T = float(input("Enter Time: "))
n = int(input("Enter number of periods per year: "))

A = PMT * (((1 + R/n) ** (n*T) - 1) / (R/n))

print("Annuity Amount =", A)
# Out:
# Enter Payment per period:  12
# Enter Rate:  13
# Enter Time:  42
# Enter number of periods per year:  2
# Annuity Amount = 36428.35315935081
